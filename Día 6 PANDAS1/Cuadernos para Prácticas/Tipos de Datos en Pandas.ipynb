# %%
import pandas as pd

# %%
datos = {'nombre': ['Pedro', 'Juan', 'Lorena'], 
         'edad': [25,39,33]}

datos
# Out:
# {'nombre': ['Pedro', 'Juan', 'Lorena'], 'edad': [25, 39, 33]}

# %%
df = pd.DataFrame(datos)
df
# Out:
#    nombre  edad
# 0   Pedro    25
# 1    Juan    39
# 2  Lorena    33

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['nombre']
# Out:
# 0     Pedro
# 1      Juan
# 2    Lorena
# Name: nombre, dtype: object

# %%
df.nombre
# Out:
# 0     Pedro
# 1      Juan
# 2    Lorena
# Name: nombre, dtype: object

# %%
type(df.nombre)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

datos = {'nombre': ['Ana', 'Luis', 'Carlos'],
                'edad': [30,25,40]}
                
df_empleados = pd.DataFrame(datos)

print(df_empleados)
# Out:
#    nombre  edad
# 0     Ana    30
# 1    Luis    25
# 2  Carlos    40

# %%
edades = pd.Series(datos['edad'])

print(type(edades))

print(edades)
# Out:
# <class 'pandas.core.series.Series'>
# 0    30
# 1    25
# 2    40
# dtype: int64

# %%
print(df_empleados.shape)
print(df_empleados.columns)
print(df_empleados.index)
# Out:
# (3, 2)
# Index(['nombre', 'edad'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)
